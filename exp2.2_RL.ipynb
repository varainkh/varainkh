# %% [markdown]
# <a href="https://colab.research.google.com/github/varainkh/varainkh/blob/main/exp2.2_RL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
data = pd.read_csv("House_Rent_Dataset.csv")

# %%
data.shape
# Out:
# (4746, 12)

# %%
data['Rent'].describe()
# Out:
# count    4.746000e+03
# mean     3.499345e+04
# std      7.810641e+04
# min      1.200000e+03
# 25%      1.000000e+04
# 50%      1.600000e+04
# 75%      3.300000e+04
# max      3.500000e+06
# Name: Rent, dtype: float64

# %%
plt.figure(figsize = (9, 5))
data['Rent'].plot(kind ="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
corrmat = data.corr()

# %%
f, ax = plt.subplots(figsize =(9, 8))
sns.heatmap(corrmat, ax = ax, cmap ="YlGnBu", linewidths = 0.1)

# %%
corrmat = data.corr();

cg = sns.clustermap(corrmat, cmap ="YlGnBu", linewidths = 0.1);
plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation = 0)
# Out:
# [None, None, None, None, None, None, None, None]

# %%
k = 15

cols = corrmat.nlargest(k, 'Rent')['Rent'].index

cm = np.corrcoef(data[cols].values.T)
f, ax = plt.subplots(figsize =(12, 10))

sns.heatmap(cm, ax = ax, cmap ="YlGnBu",
            linewidths = 0.1, yticklabels = cols.values,
                              xticklabels = cols.values)
